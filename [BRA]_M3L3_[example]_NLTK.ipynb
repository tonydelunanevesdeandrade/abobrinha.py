# %% [markdown]
# <a href="https://colab.research.google.com/github/tonydelunanevesdeandrade/abobrinha.py/blob/main/%5BBRA%5D_M3L3_%5Bexample%5D_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funções Básicas NLTK

# %% [markdown]
# ## Importação de Bibliotecas

# %%
# !pip install wordcloud
# !pip install pymorphy3

import pymorphy3
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from wordcloud import WordCloud
from matplotlib import pyplot as plt

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 69.4 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text = '''
    Esta é a casa que Jack construiu.
Este é o malte que ficou na casa que Jack construiu.
Este é o rato que comeu o malte
Que ficou na casa que Jack construiu.
Este é o gato que matou o rato
Que comeu o malte que ficou na casa que Jack construiu.
Este é o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
Esta é a vaca com o chifre amassado
Que arremessou o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
Esta é a donzela, toda desolada
Que ordenhou a vaca com o chifre amassado
Que arremessou o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
Este é o homem todo esfarrapado e rasgado
Que beijou a donzela toda desolada
Que ordenhou a vaca com o chifre amassado
Que arremessou o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
Este é o padre, todo barbeado e tosquiado
Que casou o homem todo esfarrapado e rasgado
Que beijou a donzela toda desolada
Que ordenhou a vaca com o chifre amassado
Que arremessou o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
Este é o galo que cantou pela manhã
Que acordou o padre todo barbeado e tosquiado
Que casou o homem todo esfarrapado e rasgado
Que beijou a donzela toda desolada
Que ordenhou a vaca com o chifre amassado
Que arremessou o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
Este é o fazendeiro semeando seu milho
Que cuidava do galo que cantou pela manhã
Que acordou o padre todo barbeado e tosquiado
Que casou o homem todo esfarrapado e rasgado
Que beijou a donzela toda desolada
Que ordenhou a vaca com o chifre amassado
Que arremessou o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
Este é o cavalo, o cão de caça e o berrante
Que pertenciam ao fazendeiro semeando seu milho
Que cuidava do galo que cantou pela manhã
Que acordou o padre todo barbeado e tosquiado
Que casou o homem todo esfarrapado e rasgado
Que beijou a donzela toda desolada
Que ordenhou a vaca com o chifre amassado
Que arremessou o cachorro que perseguiu o gato
Que matou o rato que comeu o malte
Que ficou na casa que Jack construiu.
          '''

# %% [markdown]
# ## Quebrando o texto em frases

# %%
sentences = sent_tokenize(text, language='portuguese')

print(20 * "-")
print(sentences)
print(20 * "-")
print("Total de Frases: ", len(sentences))
# Out:
# --------------------
# ...

# %% [markdown]
# ## Deletar palavras de interrupção

# %%
stop_words = set(stopwords.words('portuguese'))

print(10 * "-", " Palavras de Interrupção ", 10 * "-")
print(stop_words)
print(20 * "-")
# Out:
# ----------  Palavras de Interrupção  ----------
# ...

# %%
words = word_tokenize(text)

print( 20 * "-")
print(words)
print(20 * "-")
print("Total de palavras no seu texto: ", len(words))
print(20 * "-")

wc = WordCloud().generate(' '.join([i for i in words]))
plt.imshow(wc)
# Out:
# --------------------
# ...

# %%
words = [word.lower() for word in words if word.isalpha()]
words = [word for word in words if word not in stop_words]

print(10 * "-", " Palavras em letra minúscula sem palavras de interrupção", 10 * "-")
print(words)
print(20 * "-")
print("Total de palavras no seu texto:", len(words))
print(20 * "-")

wc = WordCloud().generate(' '.join([i for i in words]))
plt.imshow(wc)
# Out:
# ----------  Palavras em letra minúscula sem palavras de interrupção ----------
# ...

# %% [markdown]
# ## Lemmatization

# %%
import inspect

def getargspec(func):
    """Compatibilidade com inspect.getargspec via getfullargspec"""
    from collections import namedtuple
    FullArgSpec = inspect.getfullargspec(func)
    ArgSpec = namedtuple('ArgSpec', 'args varargs keywords defaults')
    return ArgSpec(FullArgSpec.args, FullArgSpec.varargs, FullArgSpec.varkw, FullArgSpec.defaults)

inspect.getargspec = getargspec

# %%
morph = pymorphy3.MorphAnalyzer()
words = [morph.parse(word)[0].normal_form for word in words]

print(10 * "-", " Palavras na forma inicial ", 10 * "-")
print(words)
print(20 * "-")
print("Total de palavras no seu texto: ", len(words))
print(20 * "-")

wc = WordCloud().generate(' '.join([i for i in words]))
plt.imshow(wc)
# Out:
# ----------  Palavras na forma inicial  ----------
# ...

# %% [markdown]
# ## Calcular a frequência de cada frase

# %%
freq_dist = FreqDist(words)
sentence_scores = {}

for i, sentence in enumerate(sentences):
    sentence_words = word_tokenize(sentence.lower())
    sentence_score = sum([freq_dist[word] for word in sentence_words if word in freq_dist])

    sentence_scores[i] = sentence_score

sentence_scores
# Out:
# {0: 36,
#  1: 58,
#  2: 78,
#  3: 96,
#  4: 112,
#  5: 141,
#  6: 159,
#  7: 179,
#  8: 195,
#  9: 207,
#  10: 215,
#  11: 226}

# %% [markdown]
# ## Filtrando frases por frequência

# %%
sorted_scores = sorted(sentence_scores.items(), key=lambda x: x[1], reverse=True)

sorted_scores
# Out:
# [(11, 226),
#  (10, 215),
#  (9, 207),
#  (8, 195),
#  (7, 179),
#  (6, 159),
#  (5, 141),
#  (4, 112),
#  (3, 96),
#  (2, 78),
#  (1, 58),
#  (0, 36)]

# %% [markdown]
# ## Sumarização do formulário

# %%
selected_sentences = sorted_scores[:1]
selected_sentences = sorted(selected_sentences)

# Sumarização do formulário
summary = ' '.join([sentences[i] for i, _ in selected_sentences])
print(summary)
# Out:
# This is the horse and the hound and the horn
# That belonged to the farmer sowing his corn
# That kept the cock that crowed in the morn
# That waked the priest all shaven and shorn
# That married the man all tattered and torn
# That kissed the maiden all forlorn
# That milked the cow with the crumpled horn
# That tossed the dog that worried the cat
# That killed the rat that ate the malt
# That lay in the house that Jack built.
